# %%
# !pip install mitosheet
# Out:
# ...
#      ---------------------------------------- 2.8/2.8 MB 1.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 149.9/149.9 kB 1.5 MB/s eta 0:00:00
# ...
#   Using cached jupyterlab-3.6.3-py3-none-any.whl (8.9 MB)
# ...
#   Attempting uninstall: jupyterlab
#     Found existing installation: jupyterlab 4.0.0
#     Uninstalling jupyterlab-4.0.0:
#       Successfully uninstalled jupyterlab-4.0.0
# ...
